# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B851-BCDA
#
#  Directory of c:\Users\RiteshKumar\ds-py\pandas
#
# 31-03-2025  06.15 AM    <DIR>          .
# 31-03-2025  06.14 AM    <DIR>          ..
# 31-03-2025  06.18 AM             2,873 pandas.ipynb
#                1 File(s)          2,873 bytes
#                2 Dir(s)  401,792,106,496 bytes free

# %%
df = pd.read_csv(r'C:\Users\RiteshKumar\Downloads\ecommerce_data\ecommerce_data\1MB\customers.csv')

# %%
df
# Out:
#        customer_id            name       city        state country  \
# 0                0      Customer_0       Pune  Maharashtra   India
# 1                1      Customer_1  Bangalore   Tamil Nadu   India
# 2                2      Customer_2  Hyderabad      Gujarat   India
# 3                3      Customer_3  Bangalore    Karnataka   India
# 4                4      Customer_4  Ahmedabad    Karnataka   India
# ...            ...             ...        ...          ...     ...
# 17648        17648  Customer_17648      Delhi        Delhi   India
# 17649        17649  Customer_17649      Delhi      Gujarat   India
# 17650        17650  Customer_17650    Kolkata   Tamil Nadu   India
# 17651        17651  Customer_17651     Mumbai  West Bengal   India
# 17652        17652  Customer_17652      Delhi  Maharashtra   India
#
#       registration_date  is_active
# 0            2023-06-29      False
# 1            2023-12-07       True
# 2            2023-10-27       True
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'name', 'city', 'state', 'country', 'registration_date',
#        'is_active'],
#       dtype='object')

# %%
a = df['customer_id']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df[['customer_id', 'name']]
# Out:
#        customer_id            name
# 0                0      Customer_0
# 1                1      Customer_1
# 2                2      Customer_2
# 3                3      Customer_3
# 4                4      Customer_4
# ...            ...             ...
# 17648        17648  Customer_17648
# 17649        17649  Customer_17649
# 17650        17650  Customer_17650
# 17651        17651  Customer_17651
# 17652        17652  Customer_17652
#
# [17653 rows x 2 columns]

# %% [markdown]
# # Read Excel File

# %%
pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel(r'C:\Users\RiteshKumar\Downloads\file_example_XLS_10.xls')
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
edf = pd.ExcelFile(r'C:\Users\RiteshKumar\Downloads\file_example_XLS_10.xls')

# %%
edf.sheet_names
# Out:
# ['Sheet1']

# %%
# read data from sheets

for i in edf.sheet_names:
    pd.read_excel(r'C:\Users\RiteshKumar\Downloads\file_example_XLS_10.xls', sheet_name = i)

# %% [markdown]
# Github - URL CSV DataSet

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
